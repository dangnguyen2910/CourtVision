# %%
from ultralytics import YOLO

# Load the YOLOv8n model
model = YOLO("yolov8n.pt")

# Train the model using the dataset
results = model.train(data="C:/Users/VINH/Desktop/comp vis/data.yaml", epochs=50, imgsz=640, batch=16)

# Validate the model
metrics = model.val()

# Test the model
results = model.predict(source="C:/Users/VINH/Desktop/comp vis/test/images", save=True)

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

# metrics = model.val(data = "data.yaml", split="test");
# print(f"mAP@0.5: {metrics.box.map50:.4f}")
# print(f"mAP@0.5:0.95: {metrics.box.map:.4f}")
# print(f"Precision: {metrics.box.p}")
# print(f"Recall: {metrics.box.r}")
# print(f"F1-Score: {metrics.box.f1}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/dangnh/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/train2/weights/best.pt")
results = model.predict(source="external_pics", save=True, conf=0.5)
# for result in results:
#     print(result.boxes) 
#     print(result.names)  
#     print(result.probs)
# Out:
# image 1/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1557.jpg: 384x640 1 Hoop, 9 Players, 1 Ref, 3.5ms
# image 2/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1558.jpg: 384x640 1 Hoop, 9 Players, 1 Ref, 3.1ms
# image 3/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1559.jpg: 384x640 1 Hoop, 12 Players, 1 Ref, 3.2ms
# image 4/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1560.jpg: 384x640 1 Hoop, 12 Players, 2 Refs, 3.2ms
# image 5/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1561.jpg: 384x640 1 Ball, 1 Hoop, 11 Players, 1 Ref, 3.4ms
# image 6/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1562.jpg: 384x640 1 Hoop, 11 Players, 1 Ref, 3.1ms
# image 7/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1563.jpg: 384x640 1 Hoop, 11 Players, 1 Ref, 3.1ms
# image 8/511 /home/dangnh/b3/cv/VINH/comp vis/external_pics/frame_1564.jpg: 384x640 1 Hoop, 11 Players, 1 Ref, 3.2ms
# ...
